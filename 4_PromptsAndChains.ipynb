# %%
from google import genai
from dotenv import load_dotenv
import os
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()

if os.environ['GEMINI_API_KEY']:
    print("key is the present")

else:
    print("key is not present or invalid")
# Out:
# key is the present

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
response = llm.invoke("Explain RAG in one short sentence").content

# %%
from langchain_core.prompts import ChatPromptTemplate


my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant that helps to create and curate posts for a social media platform."),
        ("human","I want to create a post about {topic}")
    ]
)

# %% [markdown]
# # Chain with Prompts

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic": "The importance of data privacy in the digital age"})
# Out:
# AIMessage(content='Okay, this is a crucial topic for the digital age! Here are a few options for a social media post about the importance of data privacy, ranging in tone and length, along with visual and hashtag suggestions.\n\n---\n\n### **Option 1: Direct & Impactful**\n\n**Caption:**\nYour data is YOUR data. In an increasingly connected world, protecting your digital privacy isn\'t just good practice – it\'s fundamental to safeguarding your identity, security, and freedom. Every click, every share, every piece of information contributes to your digital footprint. Take control of it!\n\n**Visual Suggestion:**\n*   A stylized lock icon with digital lines flowing into it.\n*   A shield protecting a person\'s silhouette in a digital landscape.\n*   An abstract image of interconnected data points with one highlighted as "private."\n\n**Hashtags:**\n#DataPrivacy #DigitalSecurity #PrivacyMatters #ProtectYourData #OnlineSafety #DigitalRights\n\n---\n\n### **Option 2: Engaging & Thought-Provoking**\n\n**Caption:**\nEver wonder how much of your life is online? From shopping habits to personal conversations, our data is constantly being collected. The importance of data privacy in the digital age can\'t be overstated. It\'s about more than just preventing spam; it\'s about preventing misuse, manipulation, and identity theft. What steps do *you* take to protect your privacy online? Share below! 👇\n\n**Visual Suggestion:**\n*   A magnifying glass over a smartphone screen showing various app icons.\n*   A person looking thoughtfully at a complex web of digital information.\n*   An infographic showing different types of data collected (browsing, location, etc.)\n\n**Hashtags:**\n#PrivacyAwareness #DigitalFootprint #CyberSecurity #DataProtection #ThinkBeforeYouShare #YourDataYourChoice\n\n---\n\n### **Option 3: Action-Oriented & Empowering**\n\n**Caption:**\nData privacy isn\'t just a concept; it\'s a practice. In the digital age, being proactive about protecting your personal information is essential.\n🔒 Use strong, unique passwords.\n⚙️ Review app permissions regularly.\n📝 Read privacy policies (or at least the summaries!).\n🌐 Be mindful of what you share publicly.\nEmpower yourself by understanding how your data is used and taking steps to secure it. Your digital well-being starts with privacy!\n\n**Visual Suggestion:**\n*   A checklist icon with digital elements.\n*   A hand holding a smartphone with secure settings visible.\n*   A "privacy dashboard" graphic.\n\n**Hashtags:**\n#PrivacyTips #DigitalWellness #CyberAwareness #SecureYourData #DataSecurity #TechTips #BeSmartOnline\n\n---\n\n### **Option 4: Short & Sweet (Good for X/Twitter or quick stories)**\n\n**Caption:**\nData privacy: It\'s not optional in the digital age. Your personal info is valuable – protect it from misuse. Stay vigilant, stay secure! #DataPrivacy #ProtectYourself #DigitalRights\n\n**Visual Suggestion:**\n*   A simple lock emoji or icon.\n*   A "private" sign in a digital font.\n\n**Hashtags:**\n#DataPrivacy #ProtectYourself #DigitalRights #OnlineSecurity\n\n---\n\n### **Tips for your post:**\n\n*   **Choose the option that best fits your brand\'s voice and your audience.**\n*   **Always include a compelling visual.** Social media posts with images or videos get significantly more engagement.\n*   **Consider adding a link** if you have a blog post or resource about data privacy you want to share.\n*   **Engage with comments!** If you ask a question, be prepared to respond.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e8c66-abb9-7f50-96a8-655a80e9c3fd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 35, 'output_tokens': 1990, 'total_tokens': 2025, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1205}})
